# %%
import numpy as np
import pandas as pd
import warnings
pd.options.mode.chained_assignment = None

# %%
books = pd.read_csv('Best_Books_Ever.csv')

# %%
books = books[['title','author','rating','genres','coverImg', 'isbn', 'characters']]

# %%
books.isnull().sum()
# Out:
# title           0
# author          0
# rating          0
# genres          0
# coverImg      605
# isbn            0
# characters      0
# dtype: int64

# %%
def convert_author(obj):
    L=[]
    counter = 0
    for i in obj:
        if i.find('(') != -1:
            i = i.split('(')[0]
        L.append(i)
    return L

# %%
books['author'] = books['author'].apply(lambda x: x.split(', ') if isinstance(x, str) else x)
books['author'] = books['author'].apply(convert_author)
books['author'] = books['author'].apply(lambda x : [i.replace(" ","") for i in x])

# %%
def convert_characters(obj):
    L=[]
    counter = 0
    for i in obj:
        if i.find('(') != -1:
            i = i.split('(')[0]
        if counter != 10:
            L.append(i)
            counter+=1
        else:
            break
    return L

# %%
import ast
books['genres'] = books['genres'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
books['genres'] = books['genres'].apply(lambda x : [i.replace(" ","") for i in x])
books['characters'] = books['characters'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
books['characters'] = books['characters'].apply(lambda x : [i.replace(" ","") for i in x])

# %%
books['characters'] = books['characters'].apply(convert_characters)

# %%
books['tags'] = books['author'] + books['genres'] + books['characters']

# %%
new_books = books[['isbn', 'title', 'tags', 'rating', 'coverImg']]

# %%
new_books['tags'] = new_books['tags'].apply(lambda x: " ".join(x))

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stemming(text):
  y = []
  for i in text.split():
    y.append(ps.stem(i))
  return " ".join(y)

# %%
new_books['tags'] = new_books['tags'].apply(stemming)

# %%
new_books.to_csv("new_books.csv", index=False)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.fit_transform(new_books['tags']).toarray()

# %%
vectors.shape
# Out:
# (52478, 5000)

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)
cv.get_feature_names_out()
# Out:
# array(['12thcenturi', '13thcenturi', '14thcenturi', '15thcenturi',
#        '16thcenturi', '17thcenturi', '18thcenturi', '19thcenturi',
#        '1stdukeofclar', '1stdukeofsuffolk', '1stdukeofwellington',
#        '1stgrade', '20thcenturi', '21stcenturi', '2ndgrade', '40k',
#        'aaron', 'aaronb', 'aaronwarneranderson', 'abbi', 'abbiglin',
#        'abdullahhussein', 'abdulmalikmujahid', 'abigailarcan',
#        'abigailroux', 'abraham', 'abrahamlincoln', 'abuhamidal', 'abus',
#        'academ', 'academia', 'accinni', 'ace', 'achil', 'action', 'activ',
#        'adam', 'adamhauptman', 'adamjeffri', 'adamvas', 'addisonmoor',
#        'adi', 'adolesc', 'adolfhitl', 'adopt', 'adrianalock',
#        'adrianivashkov', 'adrianmol', 'adriennethompson', 'adult',
#        'adultfict', 'adventur', 'aenea', 'africa', 'africanamerican',
#        'africanamericanliteratur', 'africanamericanrom',
#        'africanliteratur', 'agamemnon', 'agatha', 'agathachristi',
#        'agricultur', 'ai', 'aidenst', 'aigl', 'aiken', 'aimeecart',
#        'aislinggrey', 'akirawatanab', 'akstyr', 'al', 'alanblunt',
#        'alanbradley', 'alandeanfost', 'alaneaald', 'alangratz',
#        'alanmoor', 'alannaoftrebond', 'alansheridan', 'alaricsaltzman',
#        'alastairreynold', 'albanianliteratur', 'albert', 'albertcamu',
#        'alberteinstein', 'albertomanguel', 'albertomoravia',
#        'albertuderzo', 'alchemi', 'alcideherveaux', 'aldiss',
#        'aldoushuxley', 'alec', 'alecíamasaofkerri', 'aleistercrowley',
#        'alejabennett', 'alejandrojodorowski', 'alejandrosanchez',
#        'aleksandrsolzhenitsyn', 'alessandratorr', 'alessandrobaricco',
#        'aletheanibley', 'alex', 'alexand', 'alexander', 'alexanderk',
#        'alexandermccallsmith', 'alexandero', 'alexanderpushkin',
#        'alexanderthegreat', 'alexandrabracken', 'alexandracoop',
#        'alexandraivi', 'alexandrapott', 'alexandreduma', 'alexandria',
#        'alexarch', 'alexariley', 'alexcross', 'alexeimaximrussel',
#        'alexhaley', 'alexi', 'alexiatarabotti', 'alexjacobi', 'alexkam',
#        'alexkava', 'alexletn', 'alexreid', 'alexrid', 'alexscarrow',
#        'alfredbirnbaum', 'alfredoalcalá', 'alfredpennyworth',
#        'alfredthegreat', 'algaliarept', 'algeria', 'algiordino',
#        'algosaibi', 'alic', 'alicebuelow', 'aliceclayton', 'alicecullen',
#        'alicedean', 'alicehoffman', 'alicemunro', 'aliceoseman',
#        'aliceseno', 'alien', 'alijaizetbegović', 'alisamullen',
#        'alismith', 'alisonweir', 'alistairmaclean', 'alita', 'alivali',
#        'allanfrewinjon', 'allanquatermain', 'allen', 'allenginsberg',
#        'allycart', 'allycondi', 'almanzowild', 'aloysiusx',
#        'alpercanıgüz', 'alternatehistori', 'alternateunivers',
#        'alternativemedicin', 'alylooni', 'alysonnoel', 'alyssaday',
#        'alyssaroseivi', 'alyxandraharvey', 'amandahock', 'amandaquick',
#        'amaranthelokdon', 'amazon', 'amber', 'ambros', 'ameliaatwater',
#        'american', 'americana', 'americancivilwar', 'americanfict',
#        'americanhistori', 'americanlawenforc', 'americanrevolut',
#        'americanrevolutionarywar', 'americasing', 'ami', 'amiekaufman',
#        'aminmaalouf', 'amish', 'amishfict', 'amitavghosh', 'amitray',
#        'amosburton', 'amour', 'amya', 'amyharmon', 'amyplum', 'amypond',
#        'amytan', 'amélienothomb', 'anakinskywalk', 'anarch',
#        'anastasiasteel', 'anatol', 'anaïsnin', 'ancient',
#        'ancienthistori', 'anderson', 'andreaadrich', 'andreacrem',
#        'andreanash', 'andreawaltz', 'andredubu', 'andrenorton', 'andrew',
#        'andrewbromfield', 'andrewcl', 'andrewgross', 'andrewryan',
#        'andrewwiggin', 'andro', 'andrzejsapkowski', 'andréanovick',
#        'andrégid', 'andymcdermott', 'andymcnab', 'angel', 'angelacart',
#        'angelam', 'angelamarson', 'angelinaj', 'angelo', 'angiesag',
#        'anguavonüberwald', 'anim', 'animalfict', 'anitablak',
#        'anitashrev', 'ann', 'anna', 'annabethchas', 'annagodbersen',
#        'annaguirr', 'annaquindlen', 'annastrong', 'annatodd', 'annazair',
#        'annbrashar', 'anncoult', 'anndruyan', 'anne', 'annebishop',
#        'anneboleyn', 'anneelisabethstengl', 'annefrank', 'annelamott',
#        'annemccaffrey', 'anneric', 'anneshirley', 'annetyl',
#        'anngoldstein', 'anniebarrow', 'anniedillard', 'annieproulx',
#        'annm', 'annpatchett', 'annrinaldi', 'annrul', 'anonym',
#        'antheabel', 'antholog', 'anthonyburgess', 'anthonyhorowitz',
#        'anthonytrollop', 'anthropolog', 'anthropomorph', 'antiracist',
#        'antoinedesaint', 'antonchekhov', 'anuholopainen', 'anya',
#        'anyaseton', 'aodhan', 'aphrodit', 'aphroditelafont', 'apocalypt',
#        'aprilhenri', 'aprilynnepik', 'arch', 'archaeolog', 'archer',
#        'architectur', 'ari', 'ariadneoliv', 'ariamontgomeri', 'ariel',
#        'arieldur', 'arimarmel', 'arishamron', 'aristophan', 'aristotl',
#        'arka', 'arkadystrugatski', 'armata', 'armentrout', 'armor',
#        'armstrong', 'arnold', 'art', 'artandphotographi', 'artdesign',
#        'artemi', 'artemisagrotera', 'artemisentreri', 'artemisfowlii',
#        'arthistori', 'arthur', 'arthurc', 'arthurconandoyl', 'arthurd',
#        'arthurhailey', 'arthurhast', 'arthurian', 'arthurkoestl',
#        'arthurmil', 'arthurphillip', 'arthurpo', 'arthurransom',
#        'arthurrimbaud', 'arthurschnitzl', 'arthurschopenhau',
#        'arthurslad', 'arthurwellesley', 'artificialintellig', 'artigo',
#        'artist', 'artoi', 'artopaasilinna', 'artspiegelman', 'artthibert',
#        'arturopérez', 'aryastark', 'asexu', 'ash', 'ashallayn', 'asher',
#        'ashleyantoinett', 'ashleystalworth', 'ashredfern', 'ashthompson',
#        'asia', 'asianliteratur', 'aslan', 'asmanadia', 'aspenleg',
#        'asperg', 'asterix', 'astridellison', 'astridlindgren', 'astrolog',
#        'astronomi', 'atheism', 'athena', 'athenanibley', 'atsushiotani',
#        'atticuso', 'audiobook', 'audrelord', 'audrey', 'audreywood',
#        'auel', 'augustderleth', 'augustenburrough', 'augustin',
#        'augustocuri', 'auguststrindberg', 'augustu', 'auntb', 'aurora',
#        'aurorarosereynold', 'australia', 'autobiographi',
#        'autumnjoneslak', 'avamil', 'avao', 'averi', 'averyast', 'avi',
#        'aviat', 'aviendha', 'ayanakahara', 'ayla', 'aylmermaud',
#        'aynrand', 'ayuutami', 'aziznesin', 'bahai', 'bahá', 'bailey',
#        'bak', 'baldwin', 'balkcom', 'ballard', 'balthazarmor',
#        'bandedessiné', 'bane', 'bangladesh', 'bank', 'bannedbook',
#        'bannion', 'barackobama', 'barak', 'barbara', 'barbaraa',
#        'barbarabray', 'barbaracooney', 'barbaradelinski', 'barbaraerskin',
#        'barbaragordon', 'barbarahambl', 'barbarahav', 'barbarakingsolv',
#        'barbarapark', 'barbarataylorbradford', 'barbaravin',
#        'barbarawright', 'barinthu', 'barker', 'barr', 'barri', 'barron',
#        'barrylyga', 'bartol', 'barton', 'basebal', 'basilard',
#        'basketbal', 'bass', 'bast', 'batman', 'baxt', 'bayaz', 'bdsm',
#        'beagl', 'bean', 'bear', 'beaton', 'beatric', 'beatrice',
#        'beatricelefoux', 'beatriceprior', 'beatrixpott', 'beatrizmendoza',
#        'beaumont', 'beautyandthebeast', 'beccafitzpatrick', 'beccaritchi',
#        'beck', 'beckyalbert', 'beckybloomwood', 'bee', 'beezusquimbi',
#        'bel', 'belgarath', 'belgian', 'belgium', 'bella', 'bellaandr',
#        'bellaforrest', 'bellajewel', 'bellasoang', 'bellaswan',
#        'bellhook', 'bello', 'belsebuub', 'belvaplain', 'ben', 'benbova',
#        'bencart', 'benedict', 'benelton', 'benitomussolini',
#        'benitopérezgaldó', 'benjamin', 'benjaminfranklin',
#        'benjaminjacobgrimm', 'benkan', 'bennet', 'bennett', 'bennyalden',
#        'beno', 'bentleylittl', 'bentonwesley', 'berg', 'bernard',
#        'bernardcornwel', 'bernardfrechtman', 'bernardmalamud',
#        'bernardscudd', 'bernardwerb', 'bernbolo', 'bernhardhennen',
#        'bernicesummerfield', 'berniekoslowski', 'berniemorri',
#        'bernstein', 'berri', 'bertoltbrecht', 'bertramwilberforcewoost',
#        'bertrandrussel', 'beshear', 'bessmarvin', 'beth', 'bethani',
#        'bethgroundwat', 'bethkeri', 'bethwiseman', 'bets', 'betsy',
#        'betsyray', 'betti', 'beverlycleari', 'beverlylewi', 'bex',
#        'biancaolivi', 'biancasolderini', 'bibhutibhushanbandyopadhyay',
#        'biblic', 'biblicalfict', 'bick', 'bilbobaggin', 'billbryson',
#        'billclinton', 'billcompton', 'billmyer', 'billo', 'billwatterson',
#        'billwillingham', 'billyblack', 'billygraham', 'biographi',
#        'biographymemoir', 'biolog', 'bird', 'bisexu', 'bishop', 'bissett',
#        'bizarrofict', 'black', 'blackcoffe', 'blackmor', 'blair',
#        'blairwaldorf', 'blakecrouch', 'blanchard', 'blaylock', 'blaze',
#        'blomberg', 'bloom', 'blue', 'bluestar', 'boardingschool', 'bob',
#        'bobbypendragon', 'bobdylan', 'bobong', 'bock', 'bodelock',
#        'bodiethoen', 'bohumilhrab', 'bone', 'bonniebry',
#        'bonniemccullough', 'bonniesilv', 'bookclub', 'bookrag', 'books',
#        'booksaboutbook', 'boorstin', 'borisakunin', 'borisstrugatski',
#        'bosch', 'boston', 'botswana', 'bowen', 'box', 'boy', 'boyslov',
#        'brad', 'bradackerman', 'bradencarmichael', 'bradi', 'bradley',
#        'brain', 'bran', 'brand', 'brandilyncollin', 'brandofamb',
#        'brandondorman', 'brandonmul', 'brandonrobert', 'brandonsanderson',
#        'brandonstark', 'branson', 'brazil', 'breewarren', 'breez',
#        'brendaashworthbarri', 'brendanreich', 'brennayovanoff',
#        'brentweek', 'brenébrown', 'breteastonelli', 'brett',
#        'bretthelquist', 'briacoolidg', 'brian', 'brianevenson',
#        'brianfreeman', 'brianfroud', 'brianjacqu', 'briank',
#        'brianmichaelbendi', 'briannarandal', 'brianrobeson',
#        'brianselznick', 'brianw', 'briarmoss', 'bridgetvreeland', 'brien',
#        'brigidkemmer', 'brit', 'britishliteratur', 'brittainyc',
#        'brockthoen', 'brodiashton', 'bromberg', 'brook', 'brookestewart',
#        'brown', 'brucebann', 'brucecameron', 'brucecampbel', 'brucecovil',
#        'bruceh', 'brucesterl', 'brucewayn', 'brunok', 'brutu',
#        'bryandavi', 'bryankonietzko', 'bryanleeo', 'bryantalbot',
#        'brycecourtenay', 'buck', 'buddhism', 'buffysumm',
#        'buffythevampireslay', 'buis', 'bulgaria', 'bulgarianliteratur',
#        'bunni', 'burg', 'burk', 'burn', 'burrough', 'bush', 'busi',
#        'busterthedog', 'butch', 'butchbriano', 'butl', 'buttercup',
#        'byakuyakuchiki', 'byatt', 'byrongoin', 'caddyrowland', 'cain',
#        'cainesoren', 'caitlinkittredg', 'caitlínr', 'cal', 'caleb',
#        'calhounblair', 'callahan', 'callum', 'calvin', 'calvino',
#        'cameliahammond', 'cameron', 'camerondokey', 'cameronjac',
#        'camillachaf', 'camillaisley', 'camillamonk', 'camillebelcourt',
#        'camilled', 'cammiemorgan', 'campbel', 'campbelljr', 'canada',
#        'canadianliteratur', 'candacec', 'candaceknoebel', 'candi',
#        'canon', 'caoxueqin', 'captainarchibaldhaddock',
#        'captainhollyshort', 'captainnemo', 'captainwilllaur', 'car',
#        'caramonmajer', 'carey', 'cariancol', 'carlhiaasen',
#        'carlislecullen', 'carlo', 'carloscastañeda', 'carlosfuent',
#        'carlosruizzafón', 'carlsagan', 'carmenlowel', 'carolematthew',
#        'carolgoodman', 'caroline', 'carolineb', 'carolineforb',
#        'carolinele', 'carolinequineringal', 'caroljordan',
#        'carollynnpearson', 'carolynkeen', 'carr', 'carrick',
#        'carrieannryan', 'carrieingal', 'carriejon', 'carrieryan',
#        'carriethoma', 'carrievaughn', 'carrol', 'carrotironfoundersson',
#        'carsoncallahan', 'carsondrew', 'carsonmccul', 'carstair', 'cart',
#        'carter', 'carterhal', 'cartoon', 'casey', 'caseywatson',
#        'cassandra', 'cassandraclar', 'cassandrapalm', 'cassialeo', 'cast',
#        'castil', 'cat', 'catarinaloss', 'catcherbel', 'categoryrom',
#        'catetiernan', 'catherin', 'catherineanderson', 'catherinebybe',
#        'catherinecrawfield', 'catherinefish', 'catherinehoward',
#        'catherinemarshal', 'catherineofaragon', 'catherynnem', 'cathol',
#        'cathycassidi', 'cathyglass', 'cavafi', 'ce', 'ceceliaahern',
#        'cecilyvonziegesar', 'celaenasardothien', 'ceri', 'cesareborgia',
#        'chadefallstar', 'chadyasutora', 'chaimpotok', 'chandahahn',
#        'chaolwestfal', 'chapterbook', 'characters', 'charlaineharri',
#        'charles', 'charlesbaudelair', 'charlesbrandon', 'charlesbukowski',
#        'charlescornick', 'charlesdarwin', 'charlesdelint',
#        'charlesdicken', 'charlesiiofengland', 'charlesingal',
#        'charlesivoffr', 'charlesm', 'charlesmartin', 'charlesr',
#        'charlesstross', 'charlesvess', 'charlesw', 'charleswallacemurri',
#        'charleydavidson', 'charlie', 'charlieadlard', 'charliehigson',
#        'charliepark', 'charlietheolderapprentic', 'charlottebrontë',
#        'charlottemira', 'chasejohnson', 'chelsealuna', 'chemistri',
#        'cherisesinclair', 'cherri', 'cherryh', 'chess', 'chester',
#        'chesterton', 'chetanbhagat', 'cheyennemccray', 'chi', 'chicklit',
#        'chiefinspectorcharlespark', 'chiefjeffreytolliv', 'children',
#        'childrensclass', 'chimamandangoziadichi', 'china', 'chinamiévil',
#        'chineseliteratur', 'chingizaitmatov', 'chloeneil', 'chrisbachalo',
#        'chrisbohjalian', 'chriscart', 'chrisclaremont', 'chriscolf',
#        'chrisd', 'chrisgrabenstein', 'chrisheimerding', 'chriskuzneski',
#        'chrismariegreen', 'chrisriddel', 'christian', 'christianfantasi',
#        'christianfict', 'christiangrey', 'christianhistoricalfict',
#        'christianliv', 'christianmackeltar', 'christiannonfict',
#        'christianozera', 'christianrom', 'christiegolden',
#        'christinadodd', 'christinahenri', 'christinalauren',
#        'christinefeehan', 'christinejohnson', 'christma', 'christoph',
#        'christophegrangé', 'christopher', 'christopherch',
#        'christophereynard', 'christophergolden', 'christopherhitchen',
#        'christophermoor', 'christopherpaolini', 'christopherpik',
#        'christopherrobin', 'christophertolkien', 'chrisvanallsburg',
#        'chriswhit', 'chriswood', 'chuck', 'chuckblack', 'chuckklosterman',
#        'chuckpalahniuk', 'church', 'churchhistori', 'churchil',
#        'cindawilliamschima', 'cinderella', 'cindybrandn', 'cindythoma',
#        'cioran', 'ciri', 'citi', 'civilwar', 'clair', 'claireamadeu',
#        'clairedanv', 'clairewashburn', 'clamp', 'claramorrow',
#        'clarencethreepwood', 'clarissa', 'clarisserenaldo', 'clark',
#        'clary', 'class', 'classic', 'classicalstudi', 'classicliteratur',
#        'claud', 'claudefriedrich', 'claudelévi', 'claudiagray',
#        'claytondanv', 'cleanrom', 'cleopatra', 'cliffnielsen',
#        'cliffordd', 'cliffrathburn', 'climatechang', 'climb',
#        'clintbarton', 'clivebark', 'clivecussl', 'cocosimon', 'code',
#        'codi', 'coetze', 'cole', 'colett', 'colinforb', 'collect',
#        'colleencobl', 'colleenhoov', 'colleenhouck', 'colleenmccullough',
#        'colleg', 'collin', 'colmtóibín', 'colummccann', 'com', 'comedi',
#        'comedian', 'comic', 'comicbook', 'comicfantasi', 'comicsbd',
#        'comicsmanga', 'comicstrip', 'comingofag', 'comix',
#        'commanderjackwhitney', 'commissarioguidobrunetti', 'commun',
#        'comput', 'computersci', 'conanthebarbarian', 'conn', 'connel',
#        'conniewilli', 'conniggulden', 'connor', 'conserv',
#        'conspiracytheori', 'constancegarnett', 'constancegreen',
#        'constancekeebl', 'constantinosp', 'contemporari',
#        'contemporaryrom', 'contributor', 'cook', 'cookbook',
#        'cookiekowalski', 'cooney', 'coop', 'cooper', 'coraghessanboyl',
#        'corey', 'corleon', 'cormacbennett', 'cormacmccarthi',
#        'corneliafunk', 'cornick', 'corrieswanson', 'corwinofamb',
#        'corydoctorow', 'corywalk', 'cotton', 'cottonmalon', 'counsel',
#        'count', 'countercultur', 'countofvaloi', 'countolaf',
#        'courtneychetwynd', 'courtneysumm', 'covey', 'cox', 'cozymysteri',
#        'craft', 'craigl', 'craigrussel', 'cran', 'crescentmoon', 'cress',
#        'cressidacowel', 'crime', 'crispin', 'crispinjamesmontgomeri',
#        'cristianeserruya', 'critic', 'cronin', 'crookedstar', 'cross',
#        'crossdress', 'crow', 'cryptozoolog', 'crystallinn',
#        'cthulhumytho', 'cuisin', 'culinari', 'cullenseabourn', 'cult',
#        'cultclass', 'cultur', 'culturalstudi', 'cum', 'curranlennart',
#        'cutmeownthroatdibbl', 'cyberpunk', 'cycl', 'cynthiaeden',
#        'cynthiahand', 'cynthiaharrod', 'cynthiavoigt', 'czechliteratur',
#        'daemonblack', 'daemonsadisadiablo', 'dahlialu', 'dahliatrav',
#        'daisukeido', 'daisy', 'daisymeadow', 'dajakisubo', 'dakin',
#        'dalailamaxiv', 'dali', 'dalinarkholin', 'dalton', 'damalirichard',
#        'damenaugust', 'damian', 'damianwayn', 'damonsalvator', 'dan',
#        'danabnett', 'danamariebel', 'danamarton', 'danastabenow',
#        'danbrown', 'dandelion', 'daneelolivaw', 'dangemeinhart',
#        'dangutman', 'danhumphrey', 'dani', 'daniel', 'danielabraham',
#        'danielc', 'danieldefo', 'danielglattau', 'danielgrigori',
#        'danielj', 'danielle', 'daniellepaig', 'daniellesteel',
#        'daniellestewart', 'danielpennac', 'danielpinkwat', 'danielquinn',
#        'danielsilva', 'danio', 'danipettrey', 'danish', 'danjolley',
#        'danni', 'dano', 'dansimmon', 'dantealighieri', 'danwel',
#        'daphnecruz', 'daphnedeluc', 'daphnedumauri', 'daphnegrimm',
#        'darickrobertson', 'dark', 'darkfantasi', 'darkmyrtallyn',
#        'darkstrip', 'darrelll', 'darrenshan', 'darrow', 'darrylzao',
#        'darussalam', 'daryndajon', 'dashiellhammett', 'davebarri',
#        'daveegg', 'davemckean', 'davestewart', 'davi', 'david', 'davida',
#        'davidanderson', 'davidbaldacci', 'davidbrin', 'daviddalglish',
#        'davided', 'davidest', 'davidfosterwallac', 'davidg',
#        'davidgemmel', 'davidhalberstam', 'davidhum', 'davidhunt',
#        'davidj', 'davidl', 'davidlevithan', 'davidlodg', 'davidmattingli',
#        'davidmccullough', 'davidmcduff', 'davidmitchel', 'davidmorrel',
#        'davidr', 'davidrain', 'davidrobert', 'davidsedari', 'davidstrorm',
#        'davidtalbot', 'davidwalliam', 'davidweb', 'davisbunn', 'day',
#        'daysaint', 'dccomic', 'dciwoodward', 'dcstaceywood', 'deankoontz',
#        'deannaraybourn', 'death', 'deathoftheendless', 'debbielaci',
#        'debbiemacomb', 'debbieviguié', 'debcaletti', 'deborahbladon',
#        'deborahcook', 'deborahelli', 'deborahst', 'dedral', 'dee',
#        'deeannegist', 'deeblack', 'deelestari', 'deepakchopra', 'del',
#        'delani', 'deliapeabodi', 'delilahd', 'delphi', 'demet', 'demon',
#        'denisebrunku', 'denisedomn', 'denisegroverswank',
#        'denisemacgregor', 'denisemariemari', 'denisjohnson', 'denmark',
#        'denniscoop', 'dennisjürgensen', 'dennisl', 'dennislehan',
#        'denniso', 'derek', 'derekgaunt', 'dereklandi', 'derrickjensen',
#        'design', 'detect', 'detectiveglenn', 'deveraux', 'devneyperri',
#        'diana', 'dianagabaldon', 'dianarowland', 'dianawynnejon',
#        'dianechamberlain', 'dianeduan', 'diannacrawford', 'diari', 'dick',
#        'dickfranc', 'dickgrayson', 'dickhil', 'dickkirrin', 'dickson',
#        'dictionari', 'diesel', 'diet', 'digger', 'dikimston',
#        'dimitribelikov', 'dinobuzzati', 'dinosaur', 'dionysu', 'dirkpitt',
#        'disabl', 'discipleship', 'diseas', 'divorc', 'divyanshmishradm',
#        'dixielynndwy', 'dixon', 'dmitri', 'doc', 'docmurdock', 'doctor',
#        'doctorow', 'doctorstrang', 'doctorvictorvondoom', 'doctorwho',
#        'dog', 'dolphstorr', 'domovoibutl', 'donaldharington', 'donaldj',
#        'donaldson', 'donbartlett', 'dondelillo', 'donitak', 'donleavi',
#        'donnaleon', 'donnel', 'donwilliam', 'dorisless', 'dorothydunnett',
#        'dorothyl', 'dougiebrimson', 'dougla', 'douglasadam',
#        'douglascoupland', 'douglaspreston', 'douglasr', 'douglasreeman',
#        'dougsato', 'doyl', 'dr', 'dracomalfoy', 'dragomir', 'dragon',
#        'dragonl', 'drake', 'drakevireo', 'drama', 'drap', 'draw',
#        'dreamoftheendless', 'drew', 'drewkarpyshyn', 'drizztdo',
#        'druanderson', 'dsbryant', 'dskevindawson', 'duanejohnson',
#        'duaneswierczynski', 'duboi', 'dudleydursley', 'duncanidaho',
#        'dungeonsanddragon', 'dunn', 'durand', 'durjoydatta',
#        'dutchliteratur', 'dy', 'dyingearth', 'dylan', 'dylanthoma',
#        'dystopia', 'eagl', 'easternphilosophi', 'ebenezermccoy',
#        'eckharttol', 'ecolog', 'econom', 'edbrubak', 'eddi', 'eddie',
#        'eddiedean', 'edgarallanpo', 'edgarriceburrough', 'edison',
#        'edithgrossman', 'edithparget', 'edithwharton', 'editor',
#        'edmcbain', 'eduardogaleano', 'educ', 'edward', 'edwardcullen',
#        'edwardg', 'edwardgibbon', 'edwardgorey', 'edwardian',
#        'edwardiiiofengland', 'edwardivofengland', 'edwardrutherfurd',
#        'edwardviofengland', 'edwardw', 'eeyor', 'egweneal', 'egypt',
#        'egyptianliteratur', 'eidem', 'eidolon', 'eileenwilk', 'el',
#        'elaineracochas', 'elaynetrakand', 'eleanor', 'eleanorofaquitain',
#        'elenaaitken', 'elenadeveraux', 'elenaferrant', 'elenagilbert',
#        'elenakyl', 'elenamichael', 'eliewiesel', 'elifshafak', 'eliot',
#        'elisabethelliot', 'elizabeth', 'elizabethbennet', 'elizabethberg',
#        'elizabethchadwick', 'elizabethchandl', 'elizabethdoylecarey',
#        'elizabethgaskel', 'elizabethgeorg', 'elizabethgilbert',
#        'elizabethgoudg', 'elizabethhaydon', 'elizabethhoyt',
#        'elizabethhunt', 'elizabethiofengland', 'elizabethjanehoward',
#        'elizabethlowel', 'elizabethmoon', 'elizabethofyork',
#        'elizabethrey', 'elizabethscott', 'elizabethwoodvil', 'ellafox',
#        'ellafrank', 'ellahaloway', 'ellasumm', 'ellekennedi', 'ellen',
#        'ellenhopkin', 'ellenschreib', 'elli', 'ellielinton', 'elliot',
#        'elmoreleonard', 'elricofmelniboné', 'elv', 'elven', 'emili',
#        'emilm', 'emilybrightwel', 'emilydickinson', 'emilyfield',
#        'emilygiffin', 'emilyrodda', 'emilyroland', 'emma', 'emmachas',
#        'emmadonoghu', 'emmahart', 'emmamarshal', 'emmanuelschmitt',
#        'emmi', 'emmuskaorczi', 'emot', 'emperorkai', 'empressofbland',
#        'en', 'engin', 'engl', 'englishliteratur', 'enidblyton',
#        'enjeliavillanueva', 'enolaholm', 'enright', 'entrepreneurship',
#        'environ', 'eoincolf', 'epic', 'epicfantasi', 'epicpoetri', 'eric',
#        'ericflint', 'erichfromm', 'erichmariaremarqu', 'erichseg',
#        'ericj', 'ericnorthman', 'ericross', 'erics', 'ericshanow',
#        'ericsinclair', 'eriklarson', 'eriknight', 'erinb', 'erinhunt',
#        'erinmccarthi', 'erinwatt', 'ernesth', 'ernesthemingway',
#        'erotica', 'eroticrom', 'erynnmangum', 'esmecullen', 'esmésqualor',
#        'esoterica', 'esp', 'esperanzadiaz', 'espionag', 'essay',
#        'estellemaskam', 'esther', 'estrada', 'ethan', 'ethansullivan',
#        'ethiopia', 'ethnographi', 'eudorawelti', 'euripid',
#        'europeanhistori', 'europeanliteratur', 'evaibbotson', 'evan',
#        'evangelineanderson', 'evanlyn', 'eve', 'evedalla', 'evelevin',
#        'evelynwaugh', 'evenewton', 'everbloom', 'eveross', 'evolut',
#        'exupéri', 'ezylryb', 'eçadequeiró', 'fabian', 'fabl', 'fae',
#        'fafhrd', 'fairi', 'fairytal', 'fairytaleretel', 'faith',
#        'faitherinhick', 'faithhunt', 'famili', 'fandom', 'fanfict',
#        'fang', 'fannieflagg', 'fantasi', 'fantasyrom',
#        'fanwelltheyoungerapprentic', 'faraday', 'farrel', 'fashion',
#        'fatherdomin', 'fatty', 'favorit', 'fayechamberlain', 'faythesand',
#        'fayweldon', 'federicogarcíalorca', 'feist', 'feliciabond',
#        'felicitybrandon', 'felix', 'femaleauthor', 'femin', 'fergusfras',
#        'fernandopessoa', 'fernmichael', 'feynman', 'fiction', 'field',
#        'fighter', 'film', 'financ', 'finn', 'finnabbott', 'finneganlan',
#        'finnishliteratur', 'fionastapl', 'firefight', 'fish', 'fishleg',
#        'fit', 'fitzchivalryfars', 'fitzgerald', 'fitzkrein',
#        'fitzwilliamdarci', 'flaherti', 'flame', 'flanneryo',
#        'flaviadeluc', 'flem', 'fletch', 'florenciabonelli', 'foali',
#        'foggynelson', 'folklor', 'folktal', 'food', 'foodanddrink',
#        'foodi', 'foodwrit', 'footbal', 'forb', 'ford', 'fordprefect',
#        'forest', 'forgottenrealm', 'forrest', 'forst', 'fost', 'foster',
#        'fox', 'fracturedfairytal', 'franc', 'francenah',
#        'francescaliablock', 'francescasimon', 'francesharding',
#        'franceshodgsonburnett', 'francinepasc', 'francinepros',
#        'francineriv', 'francisa', 'franciscrawfordoflymond',
#        'francisokumu', 'franheckrott', 'frank', 'frankbaum',
#        'frankbeddor', 'frankd', 'franke', 'frankfrazetta', 'frankhardi',
#        'frankherbert', 'franklind', 'franklinw', 'frankmccourt',
#        'frankmil', 'frankquit', 'frankwarren', 'fransdewa', 'franzkafka',
#        'françoisesagan', 'fray', 'frazier', 'freddiethreepwood',
#        'frederickdouglass', 'frederickforsyth', 'fredrikbackman',
#        'frenchliteratur', 'frenchrevolut', 'freyanorth', 'freyweilhausen',
#        'friedman', 'friedrichdürrenmatt', 'friedrichengel',
#        'friedrichnietzsch', 'fritzleib', 'frost', 'futur', 'futurist',
#        'fyodordostoyevski', 'gabe', 'gabriel', 'gabrielallon',
#        'gabrieldubeau', 'gabrielgarcíamárquez', 'gabriellezevin',
#        'gabrielrodríguez', 'gailcarrig', 'gailcarsonlevin', 'gakutsugano',
#        'galahadthreepwood', 'galen', 'galileogalilei', 'game',
#        'gamedesign', 'gandalf', 'garden', 'garfieldreeves', 'garion',
#        'garthenni', 'garthnix', 'garthwilliam', 'garylarson',
#        'garypaulsen', 'garysmalley', 'gasman', 'gass', 'gay', 'gayfict',
#        'gayfory', 'gayleforman', 'ged', 'geek', 'geisl', 'genashowalt',
#        'gender', 'genderandsexu', 'genderqu', 'genderstudi',
#        'geneluenyang', 'genet', 'genevievelefoux', 'genewolf',
#        'genghiskhan', 'gentleman', 'gentri', 'geoffjohn', 'geographi',
#        'geolog', 'georg', 'george', 'georgebernardshaw', 'georgedoolittl',
#        'georgeeliot', 'georgefayn', 'georgekirrin', 'georgelovelac',
#        'georgemacdonald', 'georgemacdonaldfras', 'georgeorwel',
#        'georgepérez', 'georger', 'georges', 'georgesaund', 'georgesmiley',
#        'georgettehey', 'georgew', 'georgewashington', 'georgian',
#        'georgianadarci', 'georgieripp', 'georginakincaid', 'gerald',
#        'geralddurrel', 'geraldn', 'geraltofrivia', 'gerardrev', 'germain',
#        'germani', 'germanliteratur', 'geronimostilton',
#        'gertrudechandlerwarn', 'gertrudestein', 'ghana', 'ghazali',
#        'ghazia', 'ghost', 'ghoststori', 'gibb', 'giladpellaeon',
#        'gilbert', 'gilbertblyth', 'gilbertmorri', 'gilesmilton', 'gilli',
#        'gillianflynn', 'ginblanco', 'gingerscott', 'ginod', 'gio',
#        'giocondabelli', 'giovannipontiero', 'glebtsipurski', 'glencook',
#        'gnaeuspompeiusmagnu', 'god', 'goddess', 'goldenagemysteri',
#        'gonjinn', 'goodreads', 'gordon', 'gordonkorman', 'gorevid',
#        'goshoaoyama', 'gothic', 'gothicrom', 'govern', 'gr',
#        'gracelivingstonhil', 'gracemakutsi', 'gradi', 'gradschool',
#        'graham', 'grahamdiamond', 'grahamgreen', 'grandmamazur',
#        'grandmère', 'grannyweatherwax', 'grantmorrison', 'granuail',
#        'graphicnovel', 'graphicnovelscom', 'graphicnovelsmanga', 'grave',
#        'gray', 'graymous', 'graypierc', 'graystrip', 'greec',
#        'greekmytholog', 'green', 'gregbear', 'gregcal', 'gregil',
#        'gregori', 'gregoridaratrazanoff', 'gregorymaguir',
#        'gregoryrabassa', 'gregrucka', 'grey', 'griffin',
#        'groverunderwood', 'guid', 'guillaumemusso', 'gurihiru',
#        'gustavedoré', 'gustaveflaubert', 'guydemaupass', 'guygavrielkay',
#        'gwenfrost', 'gylfi', 'gōikeyamada', 'hacker', 'hade',
#        'hadrianblackwat', 'hajimeisayama', 'hajjahmad', 'hakangünday',
#        'hakim', 'hal', 'halloran', 'halloween', 'halto', 'hamilton',
#        'hammond', 'hank', 'hannahbonn', 'hannahgruen', 'hannahhowel',
#        'hannamarin', 'hans', 'hanschristianandersen', 'hansen', 'hanson',
#        'hapcollin', 'har', 'hara', 'hardboil', 'hardsciencefict', 'harem',
#        'harikumar', 'hariseldon', 'harlancoben', 'harlanellison',
#        'harlequin', 'harlequinheartwarm', 'harlequinrom', 'harleyquinn',
#        'haroldbloom', 'haroldrobbin', 'harperbentley', 'harpersloan',
#        'harri', 'harrison', 'harry', 'harrydresden', 'harryharrison',
#        'harryhol', 'harrykemelman', 'harrypagetflashman', 'hart',
#        'harukimurakami', 'harvey', 'harveyd', 'hasanalitoptaş',
#        'hathaway', 'hattermadigan', 'havelockvetinari',
#        'haveyouseenthisgirl', 'hawk', 'hawkesnow', 'hay', 'hayaomiyazaki',
#        'hayden', 'hazel', 'health', 'healthcar', 'hearn', 'heather',
#        'heatherbrew', 'heatherkillough', 'heathervogelfrederick',
#        'heathluck', 'hectordesilva', 'hectoroftroy', 'heinlein',
#        'heinrichböl', 'heis', 'helen', 'helenahunt', 'helendunmor',
#        'helenkel', 'helenoftroy', 'hellboy', 'henningmankel', 'henri',
#        'henrij', 'henrikibsen', 'henry', 'henryalden', 'henrychinaski',
#        'henrydavidthoreau', 'henryh', 'henryiiofengland', 'henryjam',
#        'henryksienkiewicz', 'henrymil', 'henryviiiofengland',
#        'henryviiofengland', 'henrywadsworthlongfellow', 'hera',
#        'heraldskif', 'herculepoirot', 'hergé', 'hermanmelvil',
#        'hermanngör', 'hermannhess', 'hermanwouk', 'heroicfantasi',
#        'hester', 'hiccup', 'hick', 'hieronymus', 'highfantasi',
#        'highschool', 'hil', 'hilarymantel', 'hilarymckay',
#        'hillaryrodhamclinton', 'hilton', 'hin', 'hinduism', 'hinton',
#        'hiphop', 'hiromuarakawa', 'histor', 'histori',
#        'historicalfantasi', 'historicalfict', 'historicalmysteri',
#        'historicalrom', 'historyandpolit', 'historyofsci', 'hobb',
#        'hockey', 'hoffman', 'hoffmann', 'hofstadt', 'hoid', 'holden',
#        'holiday', 'holland', 'holli', 'hollingdal', 'hollyblack',
#        'hollyblackston', 'hollybourn', 'holm', 'holocaust', 'holt',
#        'homer', 'homeryanno', 'honeyjorgenson', 'honorraconteur',
#        'honorédebalzac', 'hope', 'hoperamsay', 'horacealtman', 'horn',
#        'hornelockwood', 'horror', 'hors', 'horserac', 'horticultur',
#        'horton', 'horu', 'howard', 'howardcurti', 'howardgoldblatt',
#        'howardroughan', 'howardzinn', 'howto', 'hsanoktayanar', 'https',
#        'hubertseljr', 'hudson', 'hugh', 'hughfras', 'hughhowey',
#        'hughmitchel', 'hugo', 'hugoaward', 'hull', 'human',
#        'humandevelop', 'humayunahm', 'humor', 'humphrey', 'hungari',
#        'hungarianliteratur', 'hunt', 'hunter', 'hunternial', 'hunters',
#        'hwahu', 'hyacinth', 'iacopobruno', 'iainbank', 'iainm',
#        'iainpear', 'ianflanneri', 'ianflem', 'ianirvin', 'ianmcewan',
#        'ianmcnab', 'ianmurray', 'ianrankin', 'ibnkathir', 'ibnqayyimal',
#        'ichigokurosaki', 'ichirōtanizaki', 'idriesshah', 'iggi', 'iii',
#        'iko', 'ilanatan', 'ill', 'illium', 'illustrator', 'ilonaandrew',
#        'ilsaj', 'ilyankeilavanway', 'immanuelk', 'india',
#        'indiadesjardin', 'indianliteratur', 'indonesianliteratur',
#        'inioasano', 'inspectorgeraldwitherspoon', 'inspectorhewitt',
#        'inspectorjapp', 'inspectorjohnrebu', 'inspectorlestrad', 'inspir',
#        'intern', 'internationaldevelop', 'internationalrel', 'internet',
#        'interracialrom', 'introduct', 'introduction', 'ionelteodoreanu',
#        'iralevin', 'iran', 'ireland', 'iren', 'irishliteratur',
#        'irisjohansen', 'irismurdoch', 'irvin', 'irvind', 'irvinewelsh',
#        'irvingston', 'irvingwallac', 'irvinirv', 'irwinshaw', 'isaac',
#        'isaacasimov', 'isaacbashevissing', 'isaacnewton', 'isabel',
#        'isabelallend', 'isabelculpep', 'isabella', 'isabellaoffr',
#        'isabelle', 'isabellelacost', 'isakdinesen', 'isana',
#        'ishmaelhoratiowang', 'islam', 'isobellecarmodi',
#        'ispettorevianello', 'israel', 'issa', 'isunahasekura', 'itali',
#        'italianliteratur', 'italocalvino', 'ivanturgenev', 'ivoandrić',
#        'ivyhisselpenni', 'ivytamwood', 'izumiev', 'izumitsubaki', 'izzy',
#        'jabbarkhan', 'jace', 'jacehammond', 'jacekpiekara', 'jaciburton',
#        'jacinclay', 'jack', 'jackaubrey', 'jackcanfield', 'jackiecollin',
#        'jackiefrench', 'jackkerouac', 'jackl', 'jackle', 'jacklondon',
#        'jackmcdevitt', 'jackmorgan', 'jackreach', 'jackrosewood',
#        'jackson', 'jackstarbright', 'jacktenpenni', 'jacktheripp',
#        'jacktownsend', 'jackvanc', 'jackyfab', 'jacob', 'jacobblack',
#        'jacobgrimm', 'jacqu', 'jacquelinecarey', 'jacquelinesusann',
#        'jacquelinewilson', 'jacquelynfrank', 'jacquepierc',
#        'jacquesrousseau', 'jacquessempé', 'jae', 'jaenelleangellin',
#        'jaimelannist', 'jaimevega', 'jaimy', 'jake', 'jakeackerman',
#        'jakechamb', 'jam', 'jame', 'jamellcrouth', 'james', 'jamesa',
#        'jamesadam', 'jamesb', 'jamesbaldwin', 'jamesbarclay', 'jamesbond',
#        'jamesc', 'jamescarlosblak', 'jamesclavel', 'jamesd', 'jamesdashn',
#        'jamese', 'jamesellroy', 'jamesemerson', 'jamesfenimorecoop',
#        'jamesfrey', 'jamesgordon', 'jameshadleychas', 'jamesherbert',
#        'jamesherriot', 'jamesjoyc', 'jamesk', 'jameskavanaugh', 'jamesl',
#        'jamesleeburk', 'jamesm', 'jamesmoriarti', 'jameso', 'jamesp',
#        'jamespatterson', 'jamesponti', 'jamesr', 'jamesrasmussen',
#        'jamesriley', 'jamesrollin', 'jamess', 'jamesstrachey',
#        'jamesthurb', 'jamesw', 'jami', 'jamiefras', 'jamielewi',
#        'jamiemcguir', 'jamilla', 'janaoliv', 'janco', 'jane',
#        'janeausten', 'janebennet', 'janeeyr', 'janefletch', 'janegoodal',
#        'janegreen', 'janejameson', 'janerizzoli', 'janeseymour',
#        'janesmiley', 'janetchapman', 'janete', 'janetevanovich',
#        'janetleecarey', 'janetteok', 'janetterallison', 'janewhitefield',
#        'janeyolen', 'janguil', 'janinehathaway', 'jankaron', 'janmorri',
#        'jannaberg', 'jannywurt', 'japan', 'japanesehistori',
#        'japaneseliteratur', 'jare', 'jaredgrac', 'jaredk', 'jasindawild',
#        'jasmineros', 'jason', 'jasonanspach', 'jasonschuyl',
#        'jasonstackhous', 'jasontodd', 'jasperfford', 'jasperhal',
#        'javiermaría', 'jawziyya', 'jax', 'jaycrownov', 'jaydescott',
#        'jaykristoff', 'jaymclean', 'jayneannkrentz', 'jayrubin', 'jazz',
#        'jean', 'jeancraigheadgeorg', 'jeanettewinterson', 'jeangenet',
#        'jeanguybeauvoir', 'jeanienefrost', 'jeanm', 'jeannebirdsal',
#        'jeannec', 'jeanneiiofburgundy', 'jeannekalogridi', 'jeanrab',
#        'jeansasson', 'jebbatcheld', 'jeff', 'jeffchristoph',
#        'jefferydeav', 'jefffuel', 'jeffkinney', 'jefflemir',
#        'jefflindsay', 'jeffreyarch', 'jeffshaara', 'jeffsmith',
#        'jeffvanderm', 'jeffw', 'jem', 'jemisin', 'jen', 'jena',
#        'jencalonita', 'jenk', 'jenkin', 'jenna', 'jennablack',
#        'jennaheap', 'jennbennett', 'jenni', 'jennifera', 'jenniferadam',
#        'jenniferannedavi', 'jenniferashley', 'jenniferbrown',
#        'jenniferchiaverini', 'jennifercrusi', 'jenniferdonnelli',
#        'jennifere', 'jenniferechol', 'jenniferestep', 'jenniferl',
#        'jenniferloren', 'jenniferlynnbarn', 'jennifermcmahon',
#        'jenniferprobst', 'jenniferroberson', 'jenniferwein',
#        'jenniferworth', 'jennyb', 'jennycarrol', 'jennycolgan',
#        'jennyhan', 'jennyhumphrey', 'jennylopez', 'jensen', 'jenturano',
#        'jephloeb', 'jeremiasgotthelf', 'jeremydanv', 'jeremyforsyth',
#        'jerichobarron', 'jerismith', 'jerom', 'jeromek', 'jerryb',
#        'jerrybridg', 'jerryedgar', 'jerrypournel', 'jerryscott',
#        'jerryspinelli', 'jesbatti', 'jessehauptman', 'jesseward',
#        'jessica', 'jessicabrodi', 'jessicaclar', 'jessicadarl',
#        'jessicadaygeorg', 'jessicashirvington', 'jessicasorensen',
#        'jessicawatson', 'jessiealden', 'jesu', 'jettmayfield', 'jev',
#        'jewele', 'jewish', 'jhumpalahiri', 'jiddukrishnamurti',
#        'jilliandodd', 'jillianhunt', 'jillianmastrano', 'jillmansel',
#        'jillmurphi', 'jillmyl', 'jillshalvi', 'jillycoop', 'jim',
#        'jimbenton', 'jimborgman', 'jimbutch', 'jimchopin', 'jimhenri',
#        'jimle', 'jimmycart', 'jimmyolsen', 'jimqwilleran', 'jimshrapshir',
#        'jimupton', 'jo', 'joachimneugroschel', 'joan', 'joanaiken',
#        'joanbauer', 'joandidion', 'joanholub', 'joannebaldwin',
#        'joanneharri', 'joanofarc', 'jobeverley', 'jocelynfray',
#        'jodiellenmalpa', 'jodilynnanderson', 'jodimeadow', 'jodipicoult',
#        'joduffi', 'joe', 'joeabercrombi', 'joedonnelli', 'joehardi',
#        'joehil', 'joekowalski', 'joellecharbonneau', 'joemorelli', 'joer',
#        'joeyamazaki', 'joeyw', 'johannalindsey', 'johannwolfgangvongoeth',
#        'john', 'johna', 'johnadam', 'johnbarrowman', 'johnbarth',
#        'johnbever', 'johnboyn', 'johnbrunn', 'johnbuchan', 'johnbunyan',
#        'johnbyrn', 'johnc', 'johncart', 'johncassaday', 'johnchristoph',
#        'johnclark', 'johnconnolli', 'johnconstantin', 'johncorwin',
#        'johnd', 'johnde', 'johndonn', 'johndospasso', 'johne',
#        'johneldredg', 'johnf', 'johnfeinstein', 'johnflanagan',
#        'johnfowl', 'johngardn', 'johngaunt', 'johngranbi', 'johngreen',
#        'johngrisham', 'johngwynn', 'johnh', 'johnhiggin', 'johni',
#        'johnirv', 'johnj', 'johnjak', 'johnk', 'johnkatzenbach',
#        'johnkeat', 'johnlecarré', 'johnlennon', 'johnm', 'johnmarcon',
#        'johnmarsden', 'johnmatthew', 'johnmeaney', 'johno',
#        'johnofengland', 'johnpatrickkennedi', 'johnpaulleon', 'johnpip',
#        'johnpritkin', 'johnr', 'johnrechi', 'johnreinharddizon',
#        'johnromitajr', 'johnross', 'johnsampson', 'johnsandford',
#        'johnsaul', 'johnscalzi', 'johnsmith', 'johnson', 'johnsteinbeck',
#        'johnston', 'johnsutherland', 'johntotleben', 'johnupdik', 'johnw',
#        'johnwatson', 'johnwilkesbooth', 'johnwilliam', 'jojomoy', 'joker',
#        'jolene', 'jolynnevaleri', 'jon', 'jona', 'jonah', 'jonahmcallist',
#        'jonasgardel', 'jonathan', 'jonathancarrol', 'jonathanco',
#        'jonathancran', 'jonathanfranzen', 'jonathanglapion',
#        'jonathanlethem', 'jonathanmaberri', 'jonathanofcont',
#        'jonathansafranfo', 'jonathanstroud', 'jonathanswift', 'jonaxx',
#        'joncartwright', 'jondalar', 'jone', 'jonesbø', 'jonf', 'jonj',
#        'jonklassen', 'jonkrakau', 'jonscieszka', 'jonskovron', 'jordan',
#        'jordiebellair', 'jordisierraifabra', 'jorgeamado', 'jorgecandeia',
#        'jorgejimenez', 'jorgeluisborg', 'joscelinverreuil',
#        'josefineottesen', 'josei', 'joseph', 'josephcampbel',
#        'josephconrad', 'josephdelaney', 'josephf', 'josephineangelini',
#        'josephm', 'josephnassis', 'josepho', 'josephsmithjr',
#        'josephstalin', 'joshi', 'joshnewman', 'josswhedon',
#        'josteingaard', 'josécarlossomoza', 'josémarzánjr',
#        'josérodriguesdossanto', 'josésaramago', 'journal', 'joyc',
#        'joycecarolo', 'joycemey', 'joycemitchel', 'joyfield', 'jr',
#        'juangomez', 'juanita', 'juanitadestra', 'judaica', 'judaism',
#        'juddlauren', 'jude', 'judedeveraux', 'judewatson',
#        'judithmcnaught', 'judithreeves', 'judyblum', 'jule', 'julesvern',
#        'julia', 'juliacameron', 'juliachild', 'juliagold', 'julian',
#        'julianbarn', 'juliandariu', 'julianmay', 'juliaquinn',
#        'juliaspencer', 'julieannepet', 'juliebeauval', 'juliegarwood',
#        'juliejam', 'juliekagawa', 'julieklassen', 'julielessman',
#        'juliemorgan', 'julietmarilli', 'juliocortázar', 'juliuscaesar',
#        'jun', 'jung', 'junieb', 'junmochizuki', 'jurado', 'justin',
#        'justino', 'justinsomp', 'juvenil', 'kade', 'kahlanamnel',
#        'kahlilgibran', 'kalki', 'kalona', 'kamigarcia', 'kanamekuran',
#        'kaoriinou', 'karelčapek', 'karench', 'karenhancock',
#        'karenhawkin', 'karenhess', 'karenkingsburi', 'karenmariemon',
#        'karenmil', 'karenrobard', 'karenros', 'karentraviss', 'karenwhit',
#        'karenwitemey', 'karinacoop', 'karinahal', 'karinslaught',
#        'karlmarx', 'karlmay', 'karloveknausgård', 'karlpopp',
#        'karlwiggin', 'karrinmurphi', 'kasiewest', 'kate', 'kateatkinson',
#        'katebrian', 'katecann', 'katedaniel', 'katedicamillo',
#        'kateelliott', 'kateforsyth', 'katemorton', 'kateo', 'kateshugak',
#        'katharinekerr', 'katherine', 'katherineappleg', 'kathis',
#        'kathleenbaldwin', 'kathleene', 'kathleeno', 'kathrynlaski',
#        'kathyreich', 'katieashley', 'katiechandl', 'katiefford',
#        'katiemacalist', 'katiemcgarri', 'katiepric', 'katrichardson',
#        'katsuhirootomo', 'katyswartz', 'kayhoop', 'kayleecavanaugh',
#        'kaylinneya', 'kayscarpetta', 'kazuekato', 'kazukibuishi',
#        'kazuoishiguro', 'kearytaylor', 'keef', 'keithhal', 'kel',
#        'kellen', 'kelleyarmstrong', 'kelli', 'kellyoram', 'kemp',
#        'kendareblak', 'kendrasorenson', 'kenfollett', 'kennedi', 'kenner',
#        'kennethh', 'kennethoppel', 'kentaromiura', 'kenya', 'keriarthur',
#        'kerr', 'kerrelynspark', 'kerstingi', 'kettricken', 'kevinbrook',
#        'kevinhearn', 'kevinj', 'kevino', 'khaledhosseini', 'kid',
#        'kieracass', 'kierstenwhit', 'kilongfellow', 'kim', 'kimberlylang',
#        'kimharrison', 'kimihirowatanuki', 'kimstanleyrobinson',
#        'kingarthur', 'kingofscot', 'kinleymacgregor', 'kiraadam', 'kirk',
#        'kirstenfullm', 'kirstenmil', 'kirstymoseley', 'kistenfelp',
#        'kisukeurahara', 'kit', 'kitto', 'kittynorvil', 'kittypryd',
#        'kiyosaki', 'kiz', 'kizmin', 'klausbaudelair', 'klune', 'knight',
#        'knit', 'know', 'knuthamsun', 'koko', 'komik', 'koonwoon',
#        'kresleycol', 'krishna', 'kristaritchi', 'kristenashley',
#        'kristencallihan', 'kristenpro', 'kristianagregori', 'kristincast',
#        'kristinhannah', 'kristofnast', 'kurtbusiek', 'kurtvonnegutjr',
#        'kynanmorgan', 'kyowakamiya', 'kyrianofthrac', 'labor', 'lacey',
#        'laceyweatherford', 'ladyhelenclyd', 'ladyjanegrey', 'lafev',
#        'lain', 'lainitaylor', 'lan', 'lanalang', 'landenparke', 'lane',
#        'lanesmith', 'langleav', 'languag', 'lanmandragoran', 'lansdal',
#        'lar', 'lara', 'laraadrian', 'lararaith', 'larissaion',
#        'larissavolokhonski', 'lark', 'larry', 'larrybrown', 'larrydixon',
#        'larrymcmurtri', 'larryniven', 'larson', 'lassit', 'latinamerican',
#        'latinamericanhistori', 'latinamericanliteratur', 'latonyapage',
#        'laura', 'laurafrausinguarino', 'lauragallegogarcía',
#        'lauragoodman', 'lauragriffin', 'laurahayward', 'lauraingallswild',
#        'lauraj', 'laurajoffenumeroff', 'laurakreitz', 'lauramartin',
#        'lauranndohn', 'laurapark', 'laurathalassa', 'lauraweakley',
#        'laurawiess', 'laurelinpaig', 'laurellk', 'laurelquincey',
#        'laurenbarnholdt', 'laurenblak', 'laurence', 'laurenchild',
#        'laurendan', 'laurenk', 'laurenmyracl', 'laurenoliv', 'laurenst',
#        'laurent', 'lauriefariastolarz', 'laurieforest',
#        'lauriehalseanderson', 'lauriej', 'laurier', 'lauryfalt',
#        'lavyrlespenc', 'law', 'lawhead', 'lawr', 'lawrenc',
#        'lawrenceblock', 'lawrencecharlessummerset', 'lawrencedurrel',
#        'layla', 'lazarjan', 'ld', 'ldsfiction', 'ldsnonfict', 'le',
#        'leadership', 'leahcornick', 'leanansidh', 'leari', 'lebanon',
#        'lee', 'leechild', 'leescoresbi', 'leesmith', 'legalthril',
#        'leguin', 'leiaorgana', 'leighbardugo', 'lemonysnicket', 'lena',
#        'lenaadam', 'lenakaligari', 'lenavalenti', 'lennox', 'lenwein',
#        'leonardo', 'leonardodavinci', 'leonardpeikoff', 'leonardpin',
#        'leontrotski', 'leonuri', 'leotolstoy', 'leovaldez', 'lesbian',
#        'lesbianfict', 'lesbianrom', 'lesleypears', 'leslielonsdale',
#        'lesliemcadam', 'lestatdelioncourt', 'levi', 'lewi', 'lewiscarrol',
#        'lexluthor', 'leya', 'lgbt', 'lia', 'liam', 'lianemoriarti',
#        'lianhearn', 'liantann', 'libbabray', 'libya', 'liciatroisi',
#        'lightnovel', 'lightwood', 'lightyagami', 'lili',
#        'lilianjacksonbraun', 'lilist', 'lilithsaintcrow', 'lilley',
#        'lillymoscovitz', 'lilybard', 'lilyyu', 'lin', 'lincoln',
#        'lincolnchild', 'lincolnpeirc', 'lindacoverdal', 'lindafairstein',
#        'lindahoward', 'lindasuepark', 'lindsaybox', 'lindsayburok',
#        'lindseykelk', 'linguist', 'linhcind', 'linwoodbarclay',
#        'lisagardn', 'lisajackson', 'lisakleypa', 'lisalutz', 'lisamcmann',
#        'lisareneejon', 'lisaschroed', 'lisascottolin', 'lisase',
#        'lisatawnbergren', 'lisiharrison', 'lissa', 'literarycritic',
#        'literaryfict', 'literatur', 'littl', 'liu', 'lizkessl',
#        'lizsutton', 'llawliet', 'lloydalexand', 'llywelynthelast',
#        'logan', 'loganch', 'loganquinn', 'logic', 'loisduncan', 'loislan',
#        'loislenski', 'loislowri', 'loismcmasterbujold', 'loki', 'lolast',
#        'long', 'loraleigh', 'lordakeldama', 'lordbyron', 'lordjohngrey',
#        'lordmaccon', 'lordpeterdeathbredonwimsey', 'lordvoldemort',
#        'loreleijam', 'loriwick', 'loui', 'louis', 'louisamayalcott',
#        'louisdebernièr', 'louisdepointedulac', 'louiseerdrich',
#        'louisepenni', 'louiserennison', 'louisl', 'louissachar', 'love',
#        'lovecraft', 'lovecraftian', 'loveinspir', 'lovestori',
#        'luanneric', 'luc', 'lucascortez', 'lucasdavenport', 'lucashunt',
#        'lucasross', 'lucianban', 'lucif',
#        'lucioagustinerosenkreutzcrăciunescu', 'luciuscorneliussulla',
#        'lucivaryaslana', 'lucreziaborgia', 'lucyfarinelli',
#        'lucyfelthous', 'lucymonro', 'lucyscor', 'luigipirandello', 'luke',
#        'lukebrandon', 'lukecastellan', 'lukegarroway', 'lukehartwel',
#        'lukeskywalk', 'lula', 'lunatorashyngu', 'lund', 'lurlenemcdaniel',
#        'lydiabennet', 'lyndonb', 'lynettenoni', 'lynn', 'lynnaustin',
#        'lynneew', 'lynnereidbank', 'lynnflewel', 'lynnkurland',
#        'lynnmorri', 'lynnviehl', 'lynsaysand', 'lyrabelacqua', 'maa',
#        'mac', 'macarthurjr', 'maceymchenri', 'machadodeassi', 'machal',
#        'mack', 'mackaylalan', 'mackenzi', 'maddox', 'madeleinebr',
#        'madeleinel', 'madeleineurban', 'madelinehunt', 'maevebinchi',
#        'magdalena', 'maggi', 'maggieo', 'maggieshayn', 'maggiestiefvat',
#        'magic', 'magicalr', 'magick', 'magnu', 'magnusban', 'mahautd',
#        'mahmouddarwish', 'maiarobert', 'majorchanningchan', 'makienjōji',
#        'malcolm', 'malcolmgladwel', 'malcolmjonesiii', 'malcolmx',
#        'maldynadomontichelu', 'malley', 'mallori', 'mallorycarmichael',
#        'mallorygrac', 'malorieblackman', 'man', 'manag', 'mandym',
#        'manga', 'mangarom', 'manhwa', 'mar', 'mara', 'marajad', 'marathi',
#        'marc', 'marcelpagnol', 'marcelproust', 'marciagruv',
#        'marcialynnmcclur', 'marciaoverstrand', 'marclevi', 'marco',
#        'marcramo', 'marcspangl', 'marcu', 'marcusantoniu',
#        'marcusliciniuscrassu', 'marcussedgwick', 'marcustulliuscicero',
#        'margaret', 'margaretatwood', 'margaretjullcosta', 'margaretlaur',
#        'margaretofanj', 'margaretpetersonhaddix', 'margaretsayerspeden',
#        'margaretstohl', 'margaretwei', 'margepierci', 'margolanagan',
#        'margueritedura', 'margueritehenri', 'mari', 'maria',
#        'mariajohnsen', 'marianazapata', 'mariankey', 'mariav', 'marie',
#        'marieantoinett', 'marieck', 'marieforc', 'marielu', 'marilynkay',
#        'marimancusi', 'mariobenedetti', 'marionzimmerbradley',
#        'mariopuzo', 'mariovargasllosa', 'marissa', 'marissamey',
#        'maritim', 'mariusderomanu', 'marjanesatrapi', 'marjoriem', 'mark',
#        'marka', 'markbuckingham', 'markcrilley', 'markdimond',
#        'markhelprin', 'marklawr', 'markm', 'markmillar', 'marktufo',
#        'marktwain', 'markusneumann', 'markuszusak', 'markvictorhansen',
#        'markwaid', 'markwalden', 'marl', 'marleneperez', 'marquisdesad',
#        'marriag', 'marsalifras', 'marshal', 'martha', 'marthawel',
#        'martialart', 'martin', 'martinami', 'martinbrown',
#        'martinheidegg', 'martinlutherk', 'martinmillar', 'marvel', 'mary',
#        'marydoriarussel', 'marydowninghahn', 'marye', 'marygracerowland',
#        'marygrandpré', 'maryhigginsclark', 'maryhoffman', 'maryingal',
#        'maryiofengland', 'maryjanicedavidson', 'maryjoputney',
#        'marykaymccoma', 'maryluc', 'marymagdalen', 'maryoliv',
#        'marypopeosborn', 'maryroach', 'maryrosewood', 'maryrussel',
#        'maryshepard', 'marystewart', 'masashikishimoto', 'mason', 'massi',
#        'matekoni', 'mathemat', 'mathewson', 'matrimcauthon',
# ...
#        'robertfabbri', 'robertfrost', 'robertgoddard', 'robertgrav',
#        'robertgreen', 'roberth', 'robertharri', 'roberti', 'robertj',
#        'robertjordan', 'robertk', 'robertkirkman', 'robertl',
#        'robertlangdon', 'robertlouisstevenson', 'robertludlum',
#        'robertlynnasprin', 'robertm', 'robertmuchamor', 'robertmunsch',
#        'robertobolaño', 'robertorastapopoulo', 'robertr', 'robertshea',
#        'robertsheckley', 'robertsilverberg', 'robertsondavi',
#        'robertston', 'robertt', 'robertw', 'robinbuss', 'robincook',
#        'robinhobb', 'robinhood', 'robinjarvi', 'robinjonesgunn',
#        'robinmckinley', 'robinreneeray', 'robins', 'robinson',
#        'robinsteven', 'robinwasserman', 'robkessl', 'robkidd', 'robot',
#        'robreg', 'robthurman', 'robyncarr', 'rocknrol', 'roddydoyl',
#        'rodneyramo', 'rodolfomartinvitangcol', 'rodriguez', 'rog',
#        'roger', 'rogerleamacbrid', 'rogermackenzi', 'rogerrheinheim',
#        'rogerzelazni', 'roland', 'rolandbarth', 'rolanddeschain',
#        'rolandsmith', 'roleplayinggam', 'romaingari', 'romainrolland',
#        'roman', 'romanc', 'romania', 'romanianliteratur', 'romanov',
#        'romant', 'romantic', 'romanticsuspens', 'ronald', 'ronalddestra',
#        'ronaldmerrick', 'ronaldreagan', 'ronanlynch', 'ronhansen',
#        'ronhubbard', 'roniekendig', 'ronweasley', 'roo', 'roosevelt',
#        'rorywilliam', 'ros', 'rosaliehal', 'rose', 'rosechristo',
#        'rosemarie', 'rosenberg', 'rosethorn', 'rosewilderlan', 'rosewynt',
#        'ross', 'roth', 'rourk', 'rowena', 'rowl', 'roycemelborn',
#        'royglenn', 'rubart', 'rubeushagrid', 'rubi', 'rudyardkipl',
#        'rudyruck', 'rukiakuchiki', 'ruleturn', 'rumi', 'runs', 'russel',
#        'russellbank', 'russellh', 'russia', 'russianhistori',
#        'russianliteratur', 'russianrevolut', 'ruth', 'ruthrendel',
#        'ruthzardo', 'rwanda', 'ryan', 'ryanfeeney', 'ryanottley',
#        'ryanschow', 'ryszardkapuściński', 'ryuk', 'ryūmurakami',
#        'sabrinagrimm', 'saetansadiablo', 'sagaborg', 'said', 'saiman',
#        'saint', 'saintdan', 'saling', 'sallyla', 'sallymorgan',
#        'salmanrushdi', 'salvator', 'salvatoremurdocca', 'sam', 'samantha',
#        'samanthatowl', 'samanthayoung', 'samcresc', 'samharri',
#        'sammerlott', 'samson', 'samtempl', 'samturn', 'samuel',
#        'samuelbeckett', 'samuelcornick', 'samuelr', 'samvim', 'sandilynn',
#        'sandrabrown', 'sandrilenefatoren', 'sandstorm', 'sansom',
#        'santamontefior', 'santiagoposteguillo', 'santinohassel',
#        'saradonati', 'saradouglass', 'sarah', 'sarahaziz',
#        'sarahbethdurst', 'sarahdessen', 'sarahj', 'sarahlark', 'sarahm',
#        'sarahmlynowski', 'sarahpark', 'sarahprinea', 'sarahreesbrennan',
#        'sarahrobinson', 'sarahstrohmey', 'sarahwat', 'saralinton',
#        'sarashepard', 'sarraman', 'saschaduncan', 'sasha', 'satyajitray',
#        'saulbellow', 'savannahlevin', 'savannahravendubrinski', 'sawy',
#        'sawyerbennett', 'say', 'scandinavianliteratur', 'scarecrow',
#        'schaeff', 'schmidt', 'school', 'schoolstori', 'schulz', 'schwab',
#        'schwartz', 'scienc', 'sciencefict', 'sciencefictionfantasi',
#        'sciencefictionrom', 'sciencenatur', 'scififantasi', 'scotland',
#        'scotlandandireland', 'scott', 'scottfitzgerald', 'scottmariani',
#        'scottmey', 'scottmoncrieff', 'scotto', 'scottsnyd', 'scottsumm',
#        'scottwesterfeld', 'scriptur', 'seananmcguir', 'seano',
#        'sebastian', 'sebastianbeach', 'sebastianfitzek', 'sedoniaguillon',
#        'seeleyjam', 'seichan', 'seidenstick', 'seinen', 'selfhelp',
#        'selinakyl', 'septimusheap', 'sequentialart', 'serbianliteratur',
#        'seregilíkoritsolunmeringilbôkthersa', 'serenavanderwoodsen',
#        'sergeilukyanenko', 'sespiansavarsin', 'seth', 'sethmortensen',
#        'sethsorenson', 'seuss', 'severn', 'severussnap', 'sexual',
#        'sexwork', 'sgt', 'shade', 'shanecollin', 'shannaswendson',
#        'shannonhal', 'shannonk', 'shannonmesseng', 'shapeshift',
#        'sharlyng', 'sharma', 'sharoncreech', 'sharonkaypenman',
#        'sharonle', 'sharonm', 'sharonsala', 'sharonshinn',
#        'shaundavidhutchinson', 'shauntan', 'shaunwhitesid', 'shawnmcmanu',
#        'shay', 'shea', 'sheevpalpatin', 'shelfoot', 'shellycran',
#        'shellylaurenston', 'shelsilverstein', 'shen', 'shepard', 'sheris',
#        'sherlockholm', 'shermanalexi', 'sherrihay', 'sherrilynkenyon',
#        'sherrylwood', 'shirleydamsgaard', 'shirleyjackson', 'shirleykubo',
#        'shojo', 'sholto', 'shonen', 'shortstori', 'shortstorycollect',
#        'shounenai', 'shungikunakamura', 'sicariu', 'sidneysheldon',
#        'siennalauren', 'sigmundbrouw', 'sigmundfreud', 'silber', 'silk',
#        'simak', 'simi', 'simmon', 'simon', 'simonedebeauvoir',
#        'simoneelkel', 'simongrac', 'simonholt', 'simonkernick',
#        'simonlewi', 'simonsingh', 'simonst', 'sin', 'sinclairlewi',
#        'singular', 'siobhanvivian', 'sirgawain', 'sirlancelot',
#        'sirmordr', 'sita', 'skeptic', 'skottieyoung', 'skylamadi',
#        'sladewilson', 'sliceoflif', 'smith', 'smither', 'snowi', 'snyd',
#        'soccer', 'social', 'socialissu', 'socialjustic', 'socialmedia',
#        'socialsci', 'socialwork', 'societi', 'sociolog', 'socrat',
#        'softwar', 'soldier', 'somanchainani', 'somersetmaugham',
#        'sonyahartnett', 'sookiestackhous', 'sophi', 'sophiadeveraux',
#        'sophialightwood', 'sophieblackal', 'sophiejordan',
#        'sophiekinsella', 'sophiemckenzi', 'sophienewman', 'soren',
#        'southafrica', 'southern', 'southerngoth', 'space', 'spaceopera',
#        'spade', 'spain', 'spanishcivilwar', 'spanishliteratur',
#        'speculativefict', 'spencerhast', 'spencerjacqu', 'spenser',
#        'spiderjerusalem', 'spiderman', 'spiritu', 'splatterpunk', 'sport',
#        'sportsrom', 'spraguedecamp', 'spythril', 'st', 'staceyjay',
#        'staciakan', 'stacya', 'stanisławlem', 'stanle', 'startrek',
#        'startrekthenextgener', 'starwar', 'steampunk', 'stefansalvator',
#        'stefanzweig', 'steffort', 'stein', 'stephanielauren',
#        'stephanieplum', 'stephen', 'stephenbaxt', 'stephenbl',
#        'stephenbrigg', 'stephenclark', 'stephencol', 'stephencran',
#        'stephene', 'stephenfri', 'stephenhawk', 'stepheniemey',
#        'stephenj', 'stephenjaygould', 'stephenjon', 'stephenk',
#        'stephenmaturin', 'stephenpaul', 'stephenr', 'stephensnyd',
#        'sterl', 'stern', 'stevealten', 'steveberri', 'stevedillon',
#        'steveept', 'stevefrench', 'stevegerb', 'stevehamak',
#        'steveleialoha', 'stevemartin', 'stevemil', 'steven',
#        'stevenbrust', 'stevenerikson', 'stevenpink', 'stevenpressfield',
#        'stevenson', 'steverog', 'stevieraejohnson', 'stewart', 'stine',
#        'stirl', 'stone', 'storytim', 'strauss', 'strykeriu', 'stuart',
#        'stuartwood', 'stylofantom', 'sudan', 'suetownsend', 'sullivan',
#        'sunayakın', 'sunni', 'sunnybaudelair', 'superhero', 'superman',
#        'supernatur', 'surreal', 'surrealsadiablo', 'surviv', 'susan',
#        'susancarrol', 'susancoop', 'susandennard', 'susanecolasanti',
#        'susanelizabethphillip', 'susanericksen', 'susanhil',
#        'susanhowatch', 'susanmalleri', 'susanmaywarren', 'susannah',
#        'susannakearsley', 'susansizemor', 'susansontag', 'susanstok',
#        'suspens', 'sustain', 'sutherland', 'suzannebrockmann',
#        'suzannecollin', 'suzanneenoch', 'suzanneweyn', 'suzannewilliam',
#        'suzannewright', 'suzanneyoung', 'suze', 'swan', 'sweden',
#        'swedishliteratur', 'swordandplanet', 'swordandsorceri',
#        'sybildeidreolgivannaramkin', 'sydneycroft', 'sydneysag',
#        'sylviaday', 'sylviaplath', 'sylviaredbird', 'sánchez',
#        'sørenkierkegaard', 'ta', 'tadwilliam', 'taherehmafi', 'tahirshah',
#        'takeshiobata', 'taliasensdaught', 'tamaraphilip', 'tameraalexand',
#        'tamihoag', 'tamorapierc', 'tandi', 'tanithle', 'taoism', 'taran',
#        'tarasivec', 'tarathornton', 'tarot', 'tarrynfish', 'tasmania',
#        'tate', 'tatebradley', 'tawfiqal', 'taylor', 'teach', 'teacher',
#        'technic', 'technolog', 'ted', 'teddekk', 'teen', 'teignmott',
#        'temerair', 'temperancebrennan', 'tennesseewilliam', 'tepp',
#        'teralynnchild', 'tereliy', 'terencekilmartin', 'teresaagn',
#        'teresamedeiro', 'teresamummert', 'terri', 'terriannarmstrong',
#        'terriannebrown', 'terriblackstock', 'terriwindl', 'terror',
#        'terrybrook', 'terrydeari', 'terrygoodkind', 'terrypratchett',
#        'tess', 'tessa', 'tessgerritsen', 'tetsuichiromiyaki', 'textbook',
#        'thaliagrac', 'theaharrison', 'theatr',
#        'thechurchofjesuschristoflatter', 'thedoctor', 'theeighthdoctor',
#        'theeleventhdoctor', 'theever', 'thefool', 'thelibrarian',
#        'theluggag', 'themast', 'theodoredreis', 'theodoreroosevelt',
#        'theodoresturgeon', 'theolog', 'theori', 'theresa', 'theseu',
#        'theseventhdoctor', 'theshrik', 'thethirddoctor',
#        'theunitedstatesofamerica', 'thewarriormaid', 'theworld',
#        'thichnhathanh', 'thoma', 'thomas', 'thomasbernhard',
#        'thomascahil', 'thomascoven', 'thomascromwel', 'thomase',
#        'thomash', 'thomashardi', 'thomasharri', 'thomashoward', 'thomasj',
#        'thomasjefferson', 'thomaslynley', 'thomasm', 'thomasmann',
#        'thomasmor', 'thomasp', 'thomaspain', 'thomasperri',
#        'thomasportarlingtontrav', 'thomaspynchon', 'thomasraith',
#        'thomassowel', 'thomassullivan', 'thomaswolf', 'thompson',
#        'thomson', 'thor', 'thorn', 'thornton', 'thrawn', 'thriller',
#        'thursdaynext', 'tibbyrollin', 'tiberiascalore', 'tiddl',
#        'tiffanyach', 'tiffanyk', 'tiffanyreisz', 'tiger', 'tigerclaw',
#        'tigger', 'tiinanunn', 'tijan', 'tilliecol', 'tillybagshaw',
#        'timdrak', 'timetravel', 'timetravelrom', 'timlahay', 'timmi',
#        'timo', 'timothi', 'timothyfindley', 'timothyzahn', 'timpark',
#        'timpow', 'timsal', 'timseeley', 'timwinton', 'tina', 'tinafolsom',
#        'tink', 'tinker', 'tintin', 'tinwoodman', 'titekubo',
#        'titusflaviusvespasianu', 'tobiaseaton', 'toby', 'toddklein',
#        'toddmccaffrey', 'todhudson', 'tohrment', 'tolkien', 'tom',
#        'tomasi', 'tomclanc', 'tomokimura', 'tomrobbin', 'tomwat',
#        'tomwolf', 'tonialeo', 'toniblak', 'tonimorrison', 'tonkedragt',
#        'tony', 'tonyakapp', 'tonyblair', 'tonydaniel', 'tonyditerlizzi',
#        'tonyhil', 'tonyross', 'tonystark', 'tool', 'toot', 'toothless',
#        'torensmith', 'toreyl', 'tori', 'toscale', 'tovejansson',
#        'traceywest', 'traci', 'traciepeterson', 'tracihard',
#        'tracyannewarren', 'tracychevali', 'tracyhickman', 'tragedi',
#        'train', 'transgend', 'translator', 'transport', 'trask', 'travel',
#        'travelogu', 'traven', 'traver', 'treasurehernandez',
#        'tremperlongmaniii', 'trentkalamack', 'trentonleestewart',
#        'trillian', 'trisanachandl', 'trissmerigold', 'trivia',
#        'trottevil', 'trudicanavan', 'truecrim', 'truestori',
#        'trumancapot', 'trump', 'tsugumiohba', 'tuck', 'tudorperiod',
#        'tuit', 'turkish', 'turkishliteratur', 'turn', 'tv', 'twilight',
#        'ty', 'tyler', 'tylergradi', 'tylerlock', 'tyrionlannist', 'tyson',
#        'uhtredofbebbanburg', 'ukrain', 'ukrainianliteratur', 'umbertoeco',
#        'umeraahm', 'unfinish', 'unicorn', 'unitedst', 'unknown', 'urban',
#        'urbanfantasi', 'urbanplan', 'urbanstudi', 'urden', 'ursu',
#        'ursulak', 'uryûishida', 'uspresid', 'utopia', 'valconyos',
#        'valek', 'valent', 'valentin', 'valentinemorgenstern',
#        'valerietripp', 'valeriomassimomanfredi', 'valmcdermid', 'vampir',
#        'van', 'vanessaabram', 'variou', 'vasilisa', 'vaughan', 'vecchio',
#        'veeski', 'vegan', 'vegetarian', 'venom', 'venu', 'ver',
#        'veranevil', 'vernondursley', 'vernorving', 'veronicarossi',
#        'veronicaroth', 'vice', 'vickipettersson', 'vickyknerli', 'victor',
#        'victorfrankenstein', 'victorg', 'victorhugo', 'victoria',
#        'victoriaashley', 'victoriaaveyard', 'victoriaholt',
#        'victoriakitchen', 'victorialauri', 'victorian', 'victoriaschwab',
#        'victormilán', 'victormollo', 'victorpelevin', 'videogam', 'vii',
#        'vikeeland', 'vikirnoffvonshried', 'vil', 'vinceflynn', 'vincent',
#        'vincentbugliosi', 'vincentvangogh', 'violet', 'violetalden',
#        'violetbaudelair', 'violetkarma', 'violetplum', 'virginiawoolf',
#        'virtualr', 'vishou', 'visualart', 'vivian', 'vivianvandeveld',
#        'vladimirlenin', 'vladimirnabokov', 'vladimirsanguinati',
#        'vladtepesh', 'vollmann', 'voltair', 'walden', 'waldenwong',
#        'walk', 'walker', 'walkerperci', 'wallac', 'wallacestegn',
#        'waltdisneycompani', 'walter', 'walterfoley', 'walterisaacson',
#        'walterkaufmann', 'waltermo', 'waltermosley', 'walterscott',
#        'walton', 'waltwhitman', 'wan', 'wankenobi', 'war', 'warcraft',
#        'ward', 'warren', 'warrenelli', 'warrensmith', 'washington',
#        'watkin', 'watson', 'watt', 'wayland', 'waylonjon',
#        'waynemcloughlin', 'waynew', 'webcom', 'wedgeantil', 'weirdfict',
#        'weirdwest', 'wendelinvandraanen', 'wendellberri', 'wendymass',
#        'werewolv', 'west', 'western', 'westernhistoricalrom',
#        'westernrom', 'whit', 'white', 'whitestorm', 'whitleystrieb',
#        'whitney', 'whitneyg', 'wicca', 'wilbursmith', 'wilder', 'wildlif',
#        'wilhelmgrimm', 'wilkiecollin', 'willacath', 'willdur', 'willi',
#        'william', 'williambannist', 'williamblak', 'williamboyd',
#        'williamc', 'williamcarloswilliam', 'williamd', 'williamfaulkn',
#        'williamflanagan', 'williamgibson', 'williamh', 'williamhar',
#        'williamherondal', 'williamhorwood', 'williamj', 'williamjoyc',
#        'williamkentkrueg', 'williaml', 'williamlanecraig',
#        'williammanchest', 'williamnicholson', 'williamr', 'williams',
#        'williamshakespear', 'williamsl', 'williamsmithback', 'williamson',
#        'williamt', 'williamweav', 'willowrosenberg', 'willtreati',
#        'willtrent', 'wilson', 'win', 'windsor', 'wine', 'winniethepooh',
#        'winstonchurchil', 'winstongraham', 'winstons', 'wint', 'witch',
#        'witchcraft', 'witoldgombrowicz', 'wizard', 'wodehous', 'wolf',
#        'wolv', 'wolverin', 'women', 'womensfict', 'womensstudi',
#        'wonderwoman', 'wood', 'woodiwiss', 'worldhistori', 'worldofdark',
#        'worldofwarcraft', 'worldwari', 'worldwarii', 'wraith', 'wrath',
#        'wred', 'wright', 'write', 'www', 'xavier', 'xcor', 'xhexania',
#        'xmen', 'yalom', 'yanatoboso', 'yaoi', 'yasminegalenorn',
#        'yasunarikawabata', 'yaşarkem', 'yeat', 'yelenazaltana', 'yennef',
#        'yiannisritso', 'ying', 'yokoumezawa', 'yoruichishihôin',
#        'yoshitakaamano', 'yoshiyukisadamoto', 'youngadult',
#        'youngadultcontemporari', 'youngadultfantasi',
#        'youngadulthistoricalfict', 'youngadultparanorm', 'youngadultrom',
#        'youngadultsciencefict', 'youngkim', 'youngread',
#        'ysandredelacourcel', 'yukicross', 'yukiomishima', 'yukitokishiro',
#        'yukoichihara', 'yumyum', 'yunakagesaki', 'yuri', 'yusufal',
#        'yusufidri', 'yusukemurata', 'yuuwatas', 'zach', 'zane',
#        'zanegrey', 'zanezacharygarrett', 'zbrewer', 'zeb', 'zee', 'zen',
#        'zerbrowski', 'zerokiryu', 'zeu', 'zimbabw', 'zoey', 'zoeyredbird',
#        'zoeysha', 'zombi', 'zoyanazyalenski', 'zsadist', 'émilezola',
#        'éric', 'öij', 'αρκάς', 'леонидпарфёнов', 'أحمدخالدتوفيق',
#        'أحمدمطر', 'أملدنقل', 'أنيسمنصور', 'إبراهيمالفقي',
#        'إحسانعبدالقدوس', 'ابنقيمالجوزية', 'ابنكثير', 'بلالفضلbelalfadl',
#        'بهاءطاهر', 'توفيقالحكيم', 'جبرانخليلجبران', 'حسنالجندي',
#        'راغبالسرجاني', 'زكينجيبمحمود', 'سيدقطب', 'طهحسين',
#        'عباسمحمودالعقاد', 'عبدالرحمنالجبرتي', 'عبدالعزيزجمالالدين',
#        'غادةالسمان', 'غازيعبدالرحمنالقصيبي', 'غسانكنفاني', 'كريمالشاذلي',
#        'محمدالغزالي', 'محمدعبدالرحمنالعريفي', 'محمدناصرالدينالألباني',
#        'محموددرويش', 'مصطفىصادقالرافعي', 'مصطفىمحمود', 'نبيلفاروق',
#        'نجيبمحفوظ', 'نزارقباني', 'يوسفإدريس', 'يوسفالسباعي', '中村春菊',
#        '枢やな'], dtype=object)

# %%
pip install annoy
# Out:
# Requirement already satisfied: annoy in /usr/local/lib/python3.11/dist-packages (1.17.3)

# %%
from annoy import AnnoyIndex
annoy_index = AnnoyIndex(vectors.shape[1], 'angular')

# %%
for i in range(vectors.shape[0]):
    annoy_index.add_item(i, vectors[i])

# Build the index with 10 trees (higher = better accuracy, more memory)
annoy_index.build(10)
# Out:
# True

# %%
annoy_index.save('Book_Recommendation.ann')
# Out:
# True

# %%
def recommend(book):
    book_index = new_books[new_books['title'] == book].index[0]
    similar_books = annoy_index.get_nns_by_item(book_index, 15)

    similar_books = [i for i in similar_books if "boxset" not in new_books.iloc[i]['title'].lower()]
    similar_books = [i for i in similar_books if "box set" not in new_books.iloc[i]['title'].lower()]
    similar_books = [i for i in similar_books if "sampler" not in new_books.iloc[i]['title'].lower()]

    similar_books = sorted(similar_books, key=lambda x: new_books.iloc[x]['rating'], reverse=True)
    print(f"Recommendations for '{new_books.loc[0, 'title']}':")
    for idx in similar_books:
      print(f"- {new_books.loc[idx, 'title']}")
    return similar_books

# %%
similar_books = recommend('The Hunger Games')
# Out:
# Recommendations for 'The Hunger Games':
# - The Hunger Games
# - Catching Fire
# - Legend
# - Mockingjay
# - Independent Study
# - Blood Red Road
# - Once
# - Graduation Day
# - Sever
# - Article 5
# - The Last Princess
# - Revealing Eden
